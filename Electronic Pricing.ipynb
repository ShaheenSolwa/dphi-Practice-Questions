# %%
import pandas as pd

data  = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Datasets/master/electronic_product/electronic_product/Training_set_label.csv" )

data.head()
# Out:
#                      id prices.availability prices.condition prices.currency  \
# 0  AVphrugr1cnluZ0-FOeH                 Yes              New             USD
# 1  AVrI6FDbv8e3D1O-lm4R                 Yes              New             USD
# 2  AVpiLlubilAPnD_xBoTa                 Yes              New             USD
# 3  AVpgQP5vLJeJML43LQbd                 Yes              New             USD
# 4  AV1YDsmoGV-KLJ3adcbe     More on the Way              New             USD
#
#                                      prices.dateSeen  prices.isSale  \
# 0          2017-05-10T20:00:00Z,2017-05-09T15:00:00Z          False
# 1  2017-10-10T02:00:00Z,2017-08-12T03:00:00Z,2017...          False
# 2  2017-10-10T19:00:00Z,2017-09-12T14:00:00Z,2017...          False
# 3  2017-09-08T05:00:00Z,2017-09-18T13:00:00Z,2017...          False
# 4                               2017-12-05T13:00:00Z           True
#
#     prices.merchant                                   prices.shipping  \
# ...

# %%
X = data.drop('price', axis = 1) # her we are droping the memType feature as this is the target and 'X' is input features, the changes are not
# made inplace as we have not used 'inplace = True'

y = data['price'] # Output/Dependent variable

# %%
X = X.select_dtypes(exclude='object')

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X,y,test_size=0.33, random_state = 365)

# %%
X_train = X_train.fillna('7521585')
X_val = X_val.fillna('7521585')

# %%
from xgboost import XGBClassifier
model = XGBClassifier()
model.fit(X_train, y_train)
y_pred=model.predict(X_val)

# %%
test = pd.read_csv('https://raw.githubusercontent.com/dphi-official/Datasets/master/electronic_product/electronic_product/Testing_set_label.csv')

# %%
X = test.select_dtypes(exclude='object')
X = X.fillna('7521585')

# %%
target = model.predict(X)

# %%
res = pd.DataFrame(target) #target is nothing but the final predictions of your model on input features of your new unseen test data
res.columns = ["prediction"]
res.to_csv("ElecPricing.csv", index=False) # the csv file will be saved locally on the same location where this notebook is located.
