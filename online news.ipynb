# %%
import pandas as pd

data  = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Datasets/master/online_news_popularity/train_set_label.csv" )

data.head()
# Out:
#                                                  url   timedelta  \
# 0  http://mashable.com/2014/05/29/beats-solo-2-re...       224.0
# 1  http://mashable.com/2014/01/16/jawbone-era-hea...       357.0
# 2    http://mashable.com/2013/06/06/snapchat-update/       581.0
# 3  http://mashable.com/2013/08/16/blogger-suicide...       510.0
# 4  http://mashable.com/2013/03/12/klout-perks-mar...       667.0
#
#     n_tokens_title   n_tokens_content   n_unique_tokens   n_non_stop_words  \
# 0              8.0              337.0          0.542424                1.0
# 1             13.0              384.0          0.577465                1.0
# 2              7.0              228.0          0.706667                1.0
# 3             13.0              192.0          0.706806                1.0
# 4              7.0              342.0          0.447020                1.0
#
#     n_non_stop_unique_tokens   num_hrefs   num_self_hrefs   num_imgs   ...     \
# ...

# %%
urls = data.url

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
data['url'] = encoder.fit_transform(urls)
data.head()
# Out:
#      url   timedelta   n_tokens_title   n_tokens_content   n_unique_tokens  \
# 0  19553       224.0              8.0              337.0          0.542424
# 1  14277       357.0             13.0              384.0          0.577465
# 2   6090       581.0              7.0              228.0          0.706667
# 3   8784       510.0             13.0              192.0          0.706806
# 4   2788       667.0              7.0              342.0          0.447020
#
#     n_non_stop_words   n_non_stop_unique_tokens   num_hrefs   num_self_hrefs  \
# 0                1.0                   0.685279         8.0              1.0
# 1                1.0                   0.750000         8.0              7.0
# 2                1.0                   0.877698         9.0              4.0
# 3                1.0                   0.808000         6.0              0.0
# 4                1.0                   0.459227         9.0              5.0
#
# ...

# %%
data.columns
# Out:
# Index(['url', ' timedelta', ' n_tokens_title', ' n_tokens_content',
#        ' n_unique_tokens', ' n_non_stop_words', ' n_non_stop_unique_tokens',
#        ' num_hrefs', ' num_self_hrefs', ' num_imgs', ' num_videos',
#        ' average_token_length', ' num_keywords', ' data_channel_is_lifestyle',
#        ' data_channel_is_entertainment', ' data_channel_is_bus',
#        ' data_channel_is_socmed', ' data_channel_is_tech',
#        ' data_channel_is_world', ' kw_min_min', ' kw_max_min', ' kw_avg_min',
#        ' kw_min_max', ' kw_max_max', ' kw_avg_max', ' kw_min_avg',
#        ' kw_max_avg', ' kw_avg_avg', ' self_reference_min_shares',
#        ' self_reference_max_shares', ' self_reference_avg_sharess',
#        ' weekday_is_monday', ' weekday_is_tuesday', ' weekday_is_wednesday',
#        ' weekday_is_thursday', ' weekday_is_friday', ' weekday_is_saturday',
#        ' weekday_is_sunday', ' is_weekend', ' LDA_00', ' LDA_01', ' LDA_02',
# ...

# %%
X = data.url
#drop([' shares'], axis=1)
Y = data[' shares']

xData = X.values
yData = Y.values

# %%
from sklearn.model_selection import train_test_split 

xTrain, xTest, yTrain, yTest = train_test_split( 
        xData, yData, test_size = 0.1, random_state = 365)

# %%
from sklearn.linear_model import LogisticRegression

classifier = LogisticRegression()
classifier.fit(xTrain, yTrain)
score = classifier.score(xTest, yTest)

score
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-d7413f15d6d3> in <module>
#       2
#       3 classifier = LogisticRegression()
# ----> 4 classifier.fit(xTrain, yTrain)
#       5 score = classifier.score(xTest, yTest)
#       6
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1523
#    1524         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
# -> 1525                          accept_large_sparse=solver != 'liblinear')
#    1526         check_classification_targets(y)
#    1527         self.classes_ = np.unique(y)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
# ...

# %%
test = pd.read_csv('https://raw.githubusercontent.com/dphi-official/Datasets/master/online_news_popularity/test_set_label.csv')

X = test.drop(['url'], axis=1)

vals = model.predict(X.values)
res = pd.DataFrame(vals)
res.columns = ["prediction"]
res.to_csv("NewsPred.csv", index = False)
