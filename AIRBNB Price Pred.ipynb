# %%
import pandas as pd

data = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Datasets/master/airbnb%20_data/airbnb_listing_train.csv" )

data.head()
# Out:
#          id                                             name    host_id  \
# 0  11602914              Luxury home 100m2+garden in center!    3123809
# 1  13289321                      East is where your home is!   10259430
# 2  40779315  Amsterdam Central - LUXURY house in BUSY STREET  224969266
# 3   7820311                       great appartment down town     693472
# 4  27346603    Private room with canal view in peaceful area   41888346
#
#    host_name  neighbourhood_group            neighbourhood  latitude  \
# 0  Marjolein                  NaN  De Pijp - Rivierenbuurt  52.35368
# 1        Ana                  NaN                 Oud-Oost  52.35728
# 2       Mark                  NaN             Centrum-West  52.37582
# 3      Ayden                  NaN               Westerpark  52.37792
# 4     Alissa                  NaN               Westerpark  52.38051
#
#    longitude        room_type  minimum_nights  number_of_reviews last_review  \
# ...

# %%
list(set(data['room_type']))
data['room_type'] = data['room_type'].map({
    'Private room':0,
    'Shared room':1, 
    'Hotel room':2,
    'Entire home/apt':3
})

data.head()
# Out:
#          id                                             name    host_id  \
# 0  11602914              Luxury home 100m2+garden in center!    3123809
# 1  13289321                      East is where your home is!   10259430
# 2  40779315  Amsterdam Central - LUXURY house in BUSY STREET  224969266
# 3   7820311                       great appartment down town     693472
# 4  27346603    Private room with canal view in peaceful area   41888346
#
#    host_name  neighbourhood_group            neighbourhood  latitude  \
# 0  Marjolein                  NaN  De Pijp - Rivierenbuurt  52.35368
# 1        Ana                  NaN                 Oud-Oost  52.35728
# 2       Mark                  NaN             Centrum-West  52.37582
# 3      Ayden                  NaN               Westerpark  52.37792
# 4     Alissa                  NaN               Westerpark  52.38051
#
#    longitude  room_type  minimum_nights  number_of_reviews last_review  \
# ...

# %%
data['neighbourhood'] = data['neighbourhood'].map({
    'Westerpark':0,
 'IJburg - Zeeburgereiland':1,
 'Bos en Lommer':2,
 'Watergraafsmeer':3,
 'Gaasperdam - Driemond':4,
 'Oud-Noord':5,
 'Zuid':6,
 'Geuzenveld - Slotermeer':7,
 'Buitenveldert - Zuidas':8,
 'Slotervaart':9,
 'Noord-Oost':10,
 'Bijlmer-Centrum':11,
 'Oostelijk Havengebied - Indische Buurt':12,
 'De Aker - Nieuw Sloten':13,
 'Osdorp':14,
 'Oud-Oost':15,
 'Bijlmer-Oost':16,
 'Centrum-Oost':17,
 'De Pijp - Rivierenbuurt':18,
 'Noord-West':19,
 'De Baarsjes - Oud-West':20,
 'Centrum-West':21
})

data.head()
# Out:
#          id                                             name    host_id  \
# 0  11602914              Luxury home 100m2+garden in center!    3123809
# 1  13289321                      East is where your home is!   10259430
# 2  40779315  Amsterdam Central - LUXURY house in BUSY STREET  224969266
# 3   7820311                       great appartment down town     693472
# 4  27346603    Private room with canal view in peaceful area   41888346
#
#    host_name  neighbourhood_group  neighbourhood  latitude  longitude  \
# 0  Marjolein                  NaN             18  52.35368    4.90177
# 1        Ana                  NaN             15  52.35728    4.92052
# 2       Mark                  NaN             21  52.37582    4.89850
# 3      Ayden                  NaN              0  52.37792    4.87300
# 4     Alissa                  NaN              0  52.38051    4.87493
#
#    room_type  minimum_nights  number_of_reviews last_review  \
# ...

# %%
X = X.select_dtypes(exclude='object')
Y = data.price

xData = X.values
yData = Y.values

# %%
from sklearn.model_selection import train_test_split 

xTrain, xTest, yTrain, yTest = train_test_split( 
        xData, yData, test_size = 0.1, random_state = 42)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
clf = RandomForestClassifier(max_depth=2, random_state=42)
clf.fit(xTrain, yTrain)
y_pred=clf.predict(xTest)
print(accuracy_score(yTest, y_pred)*100)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-96e480c15e24> in <module>
#       2 from sklearn.metrics import accuracy_score
#       3 clf = RandomForestClassifier(max_depth=2000, random_state=42)
# ----> 4 clf.fit(xTrain, yTrain)
#       5 y_pred=clf.predict(xTest)
#       6 print(accuracy_score(yTest, y_pred)*100)
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     381                     verbose=self.verbose, class_weight=self.class_weight,
#     382                     n_samples_bootstrap=n_samples_bootstrap)
# --> 383                 for i, t in enumerate(trees))
#     384
#     385             # Collect newly grown trees
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1005                 self._iterating = self._original_iterator is not None
#    1006
# ...

# %%
test = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Datasets/master/airbnb%20_data/airbnb_listing_validate.csv")

# %%
list(set(test['room_type']))
test['room_type'] = test['room_type'].map({
    'Private room':0,
    'Shared room':1, 
    'Hotel room':2,
    'Entire home/apt':3
})

test['neighbourhood'] = test['neighbourhood'].map({
    'Westerpark':0,
 'IJburg - Zeeburgereiland':1,
 'Bos en Lommer':2,
 'Watergraafsmeer':3,
 'Gaasperdam - Driemond':4,
 'Oud-Noord':5,
 'Zuid':6,
 'Geuzenveld - Slotermeer':7,
 'Buitenveldert - Zuidas':8,
 'Slotervaart':9,
 'Noord-Oost':10,
 'Bijlmer-Centrum':11,
 'Oostelijk Havengebied - Indische Buurt':12,
 'De Aker - Nieuw Sloten':13,
 'Osdorp':14,
 'Oud-Oost':15,
 'Bijlmer-Oost':16,
 'Centrum-Oost':17,
 'De Pijp - Rivierenbuurt':18,
 'Noord-West':19,
 'De Baarsjes - Oud-West':20,
 'Centrum-West':21
})

x = test.select_dtypes(exclude='object')
x = x.fillna('786')

# %%
vals = logreg.predict(x.values)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-9c71ea2e201f> in <module>
# ----> 1 vals = logreg.predict(x.values)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     291             Predicted class label per sample.
#     292         """
# --> 293         scores = self.decision_function(X)
#     294         if len(scores.shape) == 1:
#     295             indices = (scores > 0).astype(np.int)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in decision_function(self, X)
#     271         if X.shape[1] != n_features:
#     272             raise ValueError("X has %d features per sample; expecting %d"
# --> 273                              % (X.shape[1], n_features))
#     274
#     275         scores = safe_sparse_dot(X, self.coef_.T,
#
# ValueError: X has 12 features per sample; expecting 5

# %%
res = pd.DataFrame(vals)
res.columns = ["prediction"]
res.to_csv("AirBNBPred.csv", index = False)
