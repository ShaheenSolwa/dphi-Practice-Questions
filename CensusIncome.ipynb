# %%
import pandas as pd

data = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Datasets/master/Census_Income/Training_set_census.csv" )

data.head()
# Out:
#    age  class_of_worker  industry_code  occupation_code  \
# 0   23          Private             43               22
# 1   24          Private             34                2
# 2   38          Private             34                2
# 3   33  Not in universe              0                0
# 4   13  Not in universe              0                0
#
#                                 education  wage_per_hour  \
# 0              Some college but no degree              0
# 1              Bachelors degree(BA AB BS)              0
# 2  Masters degree(MA MS MEng MEd MSW MBA)              0
# 3                    High school graduate              0
# 4                                Children              0
#
#   enrolled_in_edu_inst_lastwk                   marital_status  \
# 0       College or university                    Never married
# 1             Not in universe                    Never married
# 2             Not in universe  Married-civilian spouse present
# ...

# %%
list(set(data.class_of_worker))
data['class_of_worker'] = data['class_of_worker'].map({
    'Self-employed-not incorporated':0,
 ' Local government':1,
 'Self-employed-incorporated':2,
 ' Self-employed-incorporated':3,
 'State government':4,
 ' Private':5,
 'Without pay':6,
 ' Federal government':7,
 'Private':8,
 'Federal government':9,
 ' State government':10,
 ' Never worked':11,
 'Never worked':12,
 'Not in universe':13,
 ' Not in universe':14,
 ' Self-employed-not incorporated':15,
 ' Without pay':16,
 'Local government':17
})
data.head()
# Out:
#    age  class_of_worker  industry_code  occupation_code  \
# 0   23                8             43               22
# 1   24                8             34                2
# 2   38                8             34                2
# 3   33               13              0                0
# 4   13               13              0                0
#
#                                 education  wage_per_hour  \
# 0              Some college but no degree              0
# 1              Bachelors degree(BA AB BS)              0
# 2  Masters degree(MA MS MEng MEd MSW MBA)              0
# 3                    High school graduate              0
# 4                                Children              0
#
#   enrolled_in_edu_inst_lastwk                   marital_status  \
# 0       College or university                    Never married
# 1             Not in universe                    Never married
# 2             Not in universe  Married-civilian spouse present
# ...

# %%
list(set(data.education))
data['education'] = data['education'].map({
    'Bachelors degree(BA AB BS)':0,
 ' 5th or 6th grade':1,
 'Masters degree(MA MS MEng MEd MSW MBA)':2,
 ' 11th grade':3,
 '1st 2nd 3rd or 4th grade':4,
 '11th grade':5,
 ' 12th grade no diploma':6,
 ' 7th and 8th grade':7,
 'Less than 1st grade':8,
 'Prof school degree (MD DDS DVM LLB JD)':9,
 ' 9th grade':10,
 ' Masters degree(MA MS MEng MEd MSW MBA)':11,
 'Associates degree-academic program':12,
 ' Associates degree-occup /vocational':13,
 ' Less than 1st grade':14,
 ' 10th grade':15,
 'Children':16,
 ' Children':17,
 ' Associates degree-academic program':18,
 '10th grade':19,
 ' 1st 2nd 3rd or 4th grade':20,
 ' Bachelors degree(BA AB BS)':21,
 '9th grade':22,
 '7th and 8th grade':23,
 ' High school graduate':24,
 ' Some college but no degree':25,
 ' Doctorate degree(PhD EdD)':26,
 'High school graduate':27,
 'Some college but no degree':28,
 '12th grade no diploma':29,
 'Associates degree-occup /vocational':30,
 '5th or 6th grade':31,
 'Doctorate degree(PhD EdD)':32,
 ' Prof school degree (MD DDS DVM LLB JD)':33
})

data.head()
# Out:
#    age  class_of_worker  industry_code  occupation_code  education  \
# 0   23                8             43               22         28
# 1   24                8             34                2          0
# 2   38                8             34                2          2
# 3   33               13              0                0         27
# 4   13               13              0                0         16
#
#    wage_per_hour enrolled_in_edu_inst_lastwk                   marital_status  \
# 0              0       College or university                    Never married
# 1              0             Not in universe                    Never married
# 2              0             Not in universe  Married-civilian spouse present
# 3              0             Not in universe  Married-civilian spouse present
# 4              0             Not in universe                    Never married
#
#                  major_industry_code           major_occupation_code  \
# ...

# %%
list(set(data.enrolled_in_edu_inst_lastwk))
data['enrolled_in_edu_inst_lastwk'] = data['enrolled_in_edu_inst_lastwk'].map({
    'High school':0,
 ' High school':1,
 'College or university':2,
 ' College or university':3,
 'Not in universe':4,
 ' Not in universe':5
})

data.head()
# Out:
#    age  class_of_worker  industry_code  occupation_code  education  \
# 0   23                8             43               22         28
# 1   24                8             34                2          0
# 2   38                8             34                2          2
# 3   33               13              0                0         27
# 4   13               13              0                0         16
#
#    wage_per_hour  enrolled_in_edu_inst_lastwk  \
# 0              0                            2
# 1              0                            4
# 2              0                            4
# 3              0                            4
# 4              0                            4
#
#                     marital_status                major_industry_code  \
# 0                    Never married                          Education
# 1                    Never married  Finance insurance and real estate
# ...

# %%
list(set(data.marital_status))
data['marital_status'] = data['marital_status'].map({
    'Married-A F spouse present':0,
 ' Married-spouse absent':1,
 'Married-spouse absent':2,
 ' Widowed':3,
 'Widowed':4,
 ' Married-A F spouse present':5,
 'Separated':6,
 ' Married-civilian spouse present':7,
 ' Divorced':8,
 'Never married':9,
 'Married-civilian spouse present':10,
 ' Never married':11,
 ' Separated':12,
 'Divorced':13
})
data.head()
# Out:
#    age  class_of_worker  industry_code  occupation_code  education  \
# 0   23                8             43               22         28
# 1   24                8             34                2          0
# 2   38                8             34                2          2
# 3   33               13              0                0         27
# 4   13               13              0                0         16
#
#    wage_per_hour  enrolled_in_edu_inst_lastwk  marital_status  \
# 0              0                            2               9
# 1              0                            4               9
# 2              0                            4              10
# 3              0                            4              10
# 4              0                            4               9
#
#                  major_industry_code           major_occupation_code  \
# 0                          Education  Adm support including clerical
# ...

# %%
list(set(data.major_industry_code))
data['major_industry_code'] = data['major_industry_code'].map({
    'Mining':0,
 'Hospital services':1,
 'Wholesale trade':2,
 'Construction':3,
 ' Transportation':4,
 ' Personal services except private HH':5,
 'Not in universe or children':6,
 ' Public administration':7,
 'Forestry and fisheries':8,
 ' Entertainment':9,
 'Personal services except private HH':10,
 ' Utilities and sanitary services':11,
 'Transportation':12,
 ' Private household services':13,
 'Agriculture':14,
 'Social services':15,
 ' Other professional services':16,
 ' Communications':17,
 ' Manufacturing-durable goods':18,
 'Entertainment':19,
 ' Manufacturing-nondurable goods':20,
 ' Business and repair services':21,
 'Finance insurance and real estate':22,
 'Retail trade':23,
 'Business and repair services':24,
 'Medical except hospital':25,
 ' Education':26,
 ' Agriculture':27,
 ' Social services':28,
 ' Mining':29,
 ' Armed Forces':30,
 ' Forestry and fisheries':31,
 'Communications':32,
 ' Wholesale trade':33,
 'Public administration':34,
 'Other professional services':35,
 'Manufacturing-nondurable goods':36,
 ' Finance insurance and real estate':37,
 'Education':38,
 'Manufacturing-durable goods':39,
 ' Medical except hospital':40,
 'Utilities and sanitary services':41,
 ' Retail trade':42,
 ' Hospital services':43,
 'Armed Forces':44,
 ' Not in universe or children':45,
 ' Construction':46,
 'Private household services':47
})

data.head()
# Out:
#    age  class_of_worker  industry_code  occupation_code  education  \
# 0   23                8             43               22         28
# 1   24                8             34                2          0
# 2   38                8             34                2          2
# 3   33               13              0                0         27
# 4   13               13              0                0         16
#
#    wage_per_hour  enrolled_in_edu_inst_lastwk  marital_status  \
# 0              0                            2               9
# 1              0                            4               9
# 2              0                            4              10
# 3              0                            4              10
# 4              0                            4               9
#
#    major_industry_code           major_occupation_code     ...       \
# 0                   38  Adm support including clerical     ...
# ...

# %%
list(set(data.major_occupation_code))
data['major_occupation_code'] = data['major_occupation_code'].map({
    'Machine operators assmblrs & inspctrs':0,
 'Sales':1,
 'Not in universe':2,
 ' Farming forestry and fishing':3,
 ' Precision production craft & repair':4,
 ' Technicians and related support':5,
 'Farming forestry and fishing':6,
 'Protective services':7,
 ' Private household services':8,
 ' Sales':9,
 'Professional specialty':10,
 'Adm support including clerical':11,
 'Precision production craft & repair':12,
 ' Adm support including clerical':13,
 ' Not in universe':14,
 ' Machine operators assmblrs & inspctrs':15,
 ' Other service':16,
 'Executive admin and managerial':17,
 ' Protective services':18,
 ' Armed Forces':19,
 ' Transportation and material moving':20,
 ' Handlers equip cleaners etc ':21,
 'Technicians and related support':22,
 'Other service':23,
 'Transportation and material moving':24,
 'Private household services':25,
 'Handlers equip cleaners etc':26,
 'Armed Forces':27,
 ' Executive admin and managerial':28,
 ' Professional specialty':29
})

data.head()
# Out:
#    age  class_of_worker  industry_code  occupation_code  education  \
# 0   23                8             43               22         28
# 1   24                8             34                2          0
# 2   38                8             34                2          2
# 3   33               13              0                0         27
# 4   13               13              0                0         16
#
#    wage_per_hour  enrolled_in_edu_inst_lastwk  marital_status  \
# 0              0                            2               9
# 1              0                            4               9
# 2              0                            4              10
# 3              0                            4              10
# 4              0                            4               9
#
#    major_industry_code  major_occupation_code     ...      country_father  \
# 0                   38                     11     ...                Peru
# ...

# %%
list(set(data.citizenship))
data['citizenship'] =  data['citizenship'].map({
    'Native- Born abroad of American Parent(s)':0,
 ' Native- Born abroad of American Parent(s)':1,
 ' Foreign born- Not a citizen of U S ':2,
 'Foreign born- U S citizen by naturalization':3,
 'Native- Born in Puerto Rico or U S Outlying':4,
 ' Native- Born in Puerto Rico or U S Outlying':5,
 'Native- Born in the United States':6,
 ' Foreign born- U S citizen by naturalization':7,
 'Foreign born- Not a citizen of U S':8,
 ' Native- Born in the United States':9
})

data.head()
# Out:
#    age  class_of_worker  industry_code  occupation_code  education  \
# 0   23                8             43               22         28
# 1   24                8             34                2          0
# 2   38                8             34                2          2
# 3   33               13              0                0         27
# 4   13               13              0                0         16
#
#    wage_per_hour  enrolled_in_edu_inst_lastwk  marital_status  \
# 0              0                            2               9
# 1              0                            4               9
# 2              0                            4              10
# 3              0                            4              10
# 4              0                            4               9
#
#    major_industry_code  major_occupation_code     ...      country_father  \
# 0                   38                     11     ...                Peru
# ...

# %%
list(set(data.fill_questionnaire_veteran_admin))
data['fill_questionnaire_veteran_admin'] = data['fill_questionnaire_veteran_admin'].map({
    ' Yes':0,
    'Yes':0, 
    ' No':1, 
    'Not in universe':2, 
    ' Not in universe':2, 
    'No':1
})

data.head()
# Out:
#    age  class_of_worker  industry_code  occupation_code  education  \
# 0   23                8             43               22         28
# 1   24                8             34                2          0
# 2   38                8             34                2          2
# 3   33               13              0                0         27
# 4   13               13              0                0         16
#
#    wage_per_hour  enrolled_in_edu_inst_lastwk  marital_status  \
# 0              0                            2               9
# 1              0                            4               9
# 2              0                            4              10
# 3              0                            4              10
# 4              0                            4               9
#
#    major_industry_code  major_occupation_code     ...      country_father  \
# 0                   38                     11     ...                Peru
# ...

# %%
data.columns
# Out:
# Index(['age', 'class_of_worker', 'industry_code', 'occupation_code',
#        'education', 'wage_per_hour', 'enrolled_in_edu_inst_lastwk',
#        'marital_status', 'major_industry_code', 'major_occupation_code',
#        'race', 'hispanic_origin', 'sex', 'member_of_labor_union',
#        'reason_for_unemployment', 'full_parttime_employment_stat',
#        'capital_gains', 'capital_losses', 'dividend_from_Stocks',
#        'tax_filer_status', 'region_of_previous_residence',
#        'state_of_previous_residence', 'd_household_family_stat',
#        'd_household_summary', 'migration_msa', 'migration_reg',
#        'migration_within_reg', 'live_1_year_ago', 'migration_sunbelt',
#        'num_person_Worked_employer', 'family_members_under_18',
#        'country_father', 'country_mother', 'country_self', 'citizenship',
#        'business_or_self_employed', 'fill_questionnaire_veteran_admin',
#        'veterans_benefits', 'weeks_worked_in_year', 'year', 'income_level'],
# ...

# %%
list(set(data.full_parttime_employment_stat))
data['full_parttime_employment_stat'] = data['full_parttime_employment_stat'].map({
    ' Unemployed full-time':0,
 'Not in labor force':1,
 ' PT for non-econ reasons usually FT':2,
 ' Children or Armed Forces':3,
 'PT for econ reasons usually FT':4,
 ' PT for econ reasons usually FT':5,
 ' Full-time schedules':6,
 'PT for non-econ reasons usually FT':7,
 ' Unemployed part- time':8,
 'Unemployed full-time':9,
 ' Not in labor force':10,
 'Full-time schedules':11,
 'Unemployed part- time':12,
 'PT for econ reasons usually PT':13,
 ' PT for econ reasons usually PT':14,
 'Children or Armed Forces':15
})
data.head()
# Out:
#    age  class_of_worker  industry_code  occupation_code  education  \
# 0   23                8             43               22         28
# 1   24                8             34                2          0
# 2   38                8             34                2          2
# 3   33               13              0                0         27
# 4   13               13              0                0         16
#
#    wage_per_hour  enrolled_in_edu_inst_lastwk  marital_status  \
# 0              0                            2               9
# 1              0                            4               9
# 2              0                            4              10
# 3              0                            4              10
# 4              0                            4               9
#
#    major_industry_code  major_occupation_code     ...      country_father  \
# 0                   38                     11     ...                Peru
# ...

# %%
data.columns
# Out:
# Index(['age', 'class_of_worker', 'industry_code', 'occupation_code',
#        'education', 'wage_per_hour', 'enrolled_in_edu_inst_lastwk',
#        'marital_status', 'major_industry_code', 'major_occupation_code',
#        'race', 'hispanic_origin', 'sex', 'member_of_labor_union',
#        'reason_for_unemployment', 'full_parttime_employment_stat',
#        'capital_gains', 'capital_losses', 'dividend_from_Stocks',
#        'tax_filer_status', 'region_of_previous_residence',
#        'state_of_previous_residence', 'd_household_family_stat',
#        'd_household_summary', 'migration_msa', 'migration_reg',
#        'migration_within_reg', 'live_1_year_ago', 'migration_sunbelt',
#        'num_person_Worked_employer', 'family_members_under_18',
#        'country_father', 'country_mother', 'country_self', 'citizenship',
#        'business_or_self_employed', 'fill_questionnaire_veteran_admin',
#        'veterans_benefits', 'weeks_worked_in_year', 'year', 'income_level'],
# ...

# %%
list(set(data.sex))
data['sex'] = data['sex'].map({
    'Female':0, ' Female':0, 'Male':1, ' Male':1
})

# %%
list(set(data.member_of_labor_union))
data['member_of_labor_union'] = data['member_of_labor_union'].map({
    ' Yes':0, 'Yes':0, ' No':1, 'Not in universe':2, ' Not in universe':2, 'No':1
})

# %%
list(set(data.reason_for_unemployment))
data['reason_for_unemployment'] = data['reason_for_unemployment'].map({
    'New entrant':0,
 ' Job loser - on layoff':1,
 ' Other job loser':2,
 'Job loser - on layoff':3,
 'Re-entrant':4,
 ' Job leaver':5,
 'Job leaver':6,
 ' New entrant':7,
 ' Re-entrant':8,
 'Not in universe':9,
 ' Not in universe':10,
 'Other job loser':11
})

# %%
list(set(data.race))
data['race'] = data['race'].map({
    'Amer Indian Aleut or Eskimo':0,
 'Asian or Pacific Islander':1,
 'Black':2,
 ' Amer Indian Aleut or Eskimo':3,
 ' Other':4,
 ' White':5,
 ' Black':6,
 'Other':4,
 ' Asian or Pacific Islander':7,
 'White':5
})

# %%
list(set(data.hispanic_origin))
data['hispanic_origin'] = data['hispanic_origin'].map({
    'nan': 0,
 ' All other':1,
 ' Chicano':2,
 'Puerto Rican':3,
 ' Central or South American':4,
 ' Puerto Rican':3,
 'Do not know':6,
 'Other Spanish':7,
 ' Other Spanish':7,
 'Mexican (Mexicano)':9,
 ' Do not know':10,
 ' Mexican (Mexicano)':9,
 'Mexican-American':12,
 'Chicano':13,
 'All other':1,
 ' Mexican-American':15,
 ' Cuban':18,
 'Central or South American':4,
 ' NA':0,
 'Cuban':18
})

# %%
list(set(data.d_household_summary))
data['d_household_summary'] = data['d_household_summary'].map({
    'Child under 18 ever married':0,
 ' Child under 18 ever married':0,
 ' Child under 18 never married':1,
 'Group Quarters- Secondary individual':2,
 ' Spouse of householder':3,
 'Nonrelative of householder':4,
 'Child 18 or older':5,
 ' Other relative of householder':4,
 ' Nonrelative of householder':6,
 ' Group Quarters- Secondary individual':2,
 'Spouse of householder':3,
 'Other relative of householder':6,
 'Child under 18 never married':1,
 ' Householder':7,
 'Householder':7,
 ' Child 18 or older':5
})

# %%
list(set(data.family_members_under_18))
data['family_members_under_18'] = data['family_members_under_18'].map({
    'Father only present':0,
 ' Mother only present':1,
 ' Neither parent present':2,
 ' Father only present':0,
 'Neither parent present':2,
 ' Both parents present':3,
 'Mother only present':1,
 'Not in universe':4,
 ' Not in universe':4,
 'Both parents present':3
})

# %%
list(set(data.family_members_under_18))
# Out:
# [0, 1, 2, 3, 4]

# %%
data[data.eq('Joint both under 65').any(1)]
# Out:
#         age  class_of_worker  industry_code  occupation_code  education  \
# 2        38                8             34                2          2
# 3        33               13              0                0         27
# 7        44                8             22               35          4
# 9        31               13              0                0         30
# 10       35                8             12                4          0
# 12       42                0             33               20         12
# 18       46               13              0                0         12
# 20       41               13              0                0         27
# 22       24                8             33               31         27
# 23       46                8             41               30         27
# 33       38                8             13               23         27
# 35       40               17             43                2         22
# ...

# %%
list(set(data.tax_filer_status))
data['tax_filer_status'] = data['tax_filer_status'].map({
    'Single':0,
 'Joint one under 65 & one 65+':1,
 'Joint both under 65':2,
 'Nonfiler':3,
 ' Nonfiler':3,
 'Joint both 65+':4,
 'Head of household':5,
 ' Joint one under 65 & one 65+':1,
 ' Joint both 65+':4,
 ' Single':0,
 ' Head of household':5,
 ' Joint both under 65':2
})

# %%
X = data[['age', 'class_of_worker', 'industry_code', 'occupation_code',
       'education', 'wage_per_hour', 'enrolled_in_edu_inst_lastwk',
       'marital_status', 'major_industry_code', 'major_occupation_code',
       'race', 'hispanic_origin', 'sex', 'member_of_labor_union',
       'reason_for_unemployment', 'full_parttime_employment_stat',
       'capital_gains', 'capital_losses', 'dividend_from_Stocks',
       'tax_filer_status', 'd_household_summary',
       'num_person_Worked_employer', 'family_members_under_18','citizenship',
       'business_or_self_employed', 'fill_questionnaire_veteran_admin',
       'veterans_benefits', 'weeks_worked_in_year', 'year']]
Y = data.income_level

xData = X.values
yData = Y.values

# %%
from sklearn.model_selection import train_test_split 

xTrain, xTest, yTrain, yTest = train_test_split( 
        xData, yData, test_size = 0.33, random_state = 365)

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
model = XGBClassifier()
model.fit(xTrain, yTrain)
y_pred=model.predict(xTest)
print(accuracy_score(yTest, y_pred)*100)
# Out:
# 95.03181818181818

# %%
census_eval = pd.read_csv('https://raw.githubusercontent.com/dphi-official/Datasets/master/Census_Income/Testing_set_census.csv')

# %%
census_eval.head()
# Out:
#    age             class_of_worker  industry_code  occupation_code  \
# 0   65             Not in universe              0                0
# 1   75             Not in universe              0                0
# 2   26             Not in universe              0                0
# 3   42  Self-employed-incorporated              2               43
# 4   35                     Private             33               26
#
#                      education  wage_per_hour enrolled_in_edu_inst_lastwk  \
# 0        12th grade no diploma              0             Not in universe
# 1   Bachelors degree(BA AB BS)              0             Not in universe
# 2         High school graduate              0             Not in universe
# 3   Bachelors degree(BA AB BS)              0             Not in universe
# 4   Some college but no degree              0             Not in universe
#
#                      marital_status          major_industry_code  \
# ...

# %%
Data = census_eval

# %%
list(set(Data.class_of_worker))
Data['class_of_worker'] = Data['class_of_worker'].map({
    'Self-employed-not incorporated':0,
 ' Local government':1,
 'Self-employed-incorporated':2,
 ' Self-employed-incorporated':3,
 'State government':4,
 ' Private':5,
 'Without pay':6,
 ' Federal government':7,
 'Private':8,
 'Federal government':9,
 ' State government':10,
 ' Never worked':11,
 'Never worked':12,
 'Not in universe':13,
 ' Not in universe':14,
 ' Self-employed-not incorporated':15,
 ' Without pay':16,
 'Local government':17
})
list(set(Data.education))
Data['education'] = Data['education'].map({
    'Bachelors degree(BA AB BS)':0,
 ' 5th or 6th grade':1,
 'Masters degree(MA MS MEng MEd MSW MBA)':2,
 ' 11th grade':3,
 '1st 2nd 3rd or 4th grade':4,
 '11th grade':5,
 ' 12th grade no diploma':6,
 ' 7th and 8th grade':7,
 'Less than 1st grade':8,
 'Prof school degree (MD DDS DVM LLB JD)':9,
 ' 9th grade':10,
 ' Masters degree(MA MS MEng MEd MSW MBA)':11,
 'Associates degree-academic program':12,
 ' Associates degree-occup /vocational':13,
 ' Less than 1st grade':14,
 ' 10th grade':15,
 'Children':16,
 ' Children':17,
 ' Associates degree-academic program':18,
 '10th grade':19,
 ' 1st 2nd 3rd or 4th grade':20,
 ' Bachelors degree(BA AB BS)':21,
 '9th grade':22,
 '7th and 8th grade':23,
 ' High school graduate':24,
 ' Some college but no degree':25,
 ' Doctorate degree(PhD EdD)':26,
 'High school graduate':27,
 'Some college but no degree':28,
 '12th grade no diploma':29,
 'Associates degree-occup /vocational':30,
 '5th or 6th grade':31,
 'Doctorate degree(PhD EdD)':32,
 ' Prof school degree (MD DDS DVM LLB JD)':33
})
list(set(Data.enrolled_in_edu_inst_lastwk))
Data['enrolled_in_edu_inst_lastwk'] = Data['enrolled_in_edu_inst_lastwk'].map({
    'High school':0,
 ' High school':1,
 'College or university':2,
 ' College or university':3,
 'Not in universe':4,
 ' Not in universe':5
})
list(set(Data.marital_status))
Data['marital_status'] = Data['marital_status'].map({
    'Married-A F spouse present':0,
 ' Married-spouse absent':1,
 'Married-spouse absent':2,
 ' Widowed':3,
 'Widowed':4,
 ' Married-A F spouse present':5,
 'Separated':6,
 ' Married-civilian spouse present':7,
 ' Divorced':8,
 'Never married':9,
 'Married-civilian spouse present':10,
 ' Never married':11,
 ' Separated':12,
 'Divorced':13
})
list(set(Data.major_industry_code))
Data['major_industry_code'] = Data['major_industry_code'].map({
    'Mining':0,
 'Hospital services':1,
 'Wholesale trade':2,
 'Construction':3,
 ' Transportation':4,
 ' Personal services except private HH':5,
 'Not in universe or children':6,
 ' Public administration':7,
 'Forestry and fisheries':8,
 ' Entertainment':9,
 'Personal services except private HH':10,
 ' Utilities and sanitary services':11,
 'Transportation':12,
 ' Private household services':13,
 'Agriculture':14,
 'Social services':15,
 ' Other professional services':16,
 ' Communications':17,
 ' Manufacturing-durable goods':18,
 'Entertainment':19,
 ' Manufacturing-nondurable goods':20,
 ' Business and repair services':21,
 'Finance insurance and real estate':22,
 'Retail trade':23,
 'Business and repair services':24,
 'Medical except hospital':25,
 ' Education':26,
 ' Agriculture':27,
 ' Social services':28,
 ' Mining':29,
 ' Armed Forces':30,
 ' Forestry and fisheries':31,
 'Communications':32,
 ' Wholesale trade':33,
 'Public administration':34,
 'Other professional services':35,
 'Manufacturing-nondurable goods':36,
 ' Finance insurance and real estate':37,
 'Education':38,
 'Manufacturing-durable goods':39,
 ' Medical except hospital':40,
 'Utilities and sanitary services':41,
 ' Retail trade':42,
 ' Hospital services':43,
 'Armed Forces':44,
 ' Not in universe or children':45,
 ' Construction':46,
 'Private household services':47
})
list(set(Data.major_occupation_code))
Data['major_occupation_code'] = Data['major_occupation_code'].map({
    'Machine operators assmblrs & inspctrs':0,
 'Sales':1,
 'Not in universe':2,
 ' Farming forestry and fishing':3,
 ' Precision production craft & repair':4,
 ' Technicians and related support':5,
 'Farming forestry and fishing':6,
 'Protective services':7,
 ' Private household services':8,
 ' Sales':9,
 'Professional specialty':10,
 'Adm support including clerical':11,
 'Precision production craft & repair':12,
 ' Adm support including clerical':13,
 ' Not in universe':14,
 ' Machine operators assmblrs & inspctrs':15,
 ' Other service':16,
 'Executive admin and managerial':17,
 ' Protective services':18,
 ' Armed Forces':19,
 ' Transportation and material moving':20,
 ' Handlers equip cleaners etc ':21,
 'Technicians and related support':22,
 'Other service':23,
 'Transportation and material moving':24,
 'Private household services':25,
 'Handlers equip cleaners etc':26,
 'Armed Forces':27,
 ' Executive admin and managerial':28,
 ' Professional specialty':29
})
list(set(Data.citizenship))
Data['citizenship'] =  Data['citizenship'].map({
    'Native- Born abroad of American Parent(s)':0,
 ' Native- Born abroad of American Parent(s)':1,
 ' Foreign born- Not a citizen of U S ':2,
 'Foreign born- U S citizen by naturalization':3,
 'Native- Born in Puerto Rico or U S Outlying':4,
 ' Native- Born in Puerto Rico or U S Outlying':5,
 'Native- Born in the United States':6,
 ' Foreign born- U S citizen by naturalization':7,
 'Foreign born- Not a citizen of U S':8,
 ' Native- Born in the United States':9
})
list(set(Data.fill_questionnaire_veteran_admin))
Data['fill_questionnaire_veteran_admin'] = Data['fill_questionnaire_veteran_admin'].map({
    ' Yes':0,
    'Yes':0, 
    ' No':1, 
    'Not in universe':2, 
    ' Not in universe':2, 
    'No':1
})
list(set(Data.full_parttime_employment_stat))
Data['full_parttime_employment_stat'] = Data['full_parttime_employment_stat'].map({
    ' Unemployed full-time':0,
 'Not in labor force':1,
 ' PT for non-econ reasons usually FT':2,
 ' Children or Armed Forces':3,
 'PT for econ reasons usually FT':4,
 ' PT for econ reasons usually FT':5,
 ' Full-time schedules':6,
 'PT for non-econ reasons usually FT':7,
 ' Unemployed part- time':8,
 'Unemployed full-time':9,
 ' Not in labor force':10,
 'Full-time schedules':11,
 'Unemployed part- time':12,
 'PT for econ reasons usually PT':13,
 ' PT for econ reasons usually PT':14,
 'Children or Armed Forces':15
})
list(set(Data.sex))
Data['sex'] = Data['sex'].map({
    'Female':0, ' Female':0, 'Male':1, ' Male':1
})
list(set(Data.member_of_labor_union))
Data['member_of_labor_union'] = Data['member_of_labor_union'].map({
    ' Yes':0, 'Yes':0, ' No':1, 'Not in universe':2, ' Not in universe':2, 'No':1
})
list(set(Data.reason_for_unemployment))
Data['reason_for_unemployment'] = Data['reason_for_unemployment'].map({
    'New entrant':0,
 ' Job loser - on layoff':1,
 ' Other job loser':2,
 'Job loser - on layoff':3,
 'Re-entrant':4,
 ' Job leaver':5,
 'Job leaver':6,
 ' New entrant':7,
 ' Re-entrant':8,
 'Not in universe':9,
 ' Not in universe':10,
 'Other job loser':11
})
list(set(Data.race))
Data['race'] = Data['race'].map({
    'Amer Indian Aleut or Eskimo':0,
 'Asian or Pacific Islander':1,
 'Black':2,
 ' Amer Indian Aleut or Eskimo':3,
 ' Other':4,
 ' White':5,
 ' Black':6,
 'Other':4,
 ' Asian or Pacific Islander':7,
 'White':5
})
list(set(Data.hispanic_origin))
Data['hispanic_origin'] = Data['hispanic_origin'].map({
    'nan': 0,
 ' All other':1,
 ' Chicano':2,
 'Puerto Rican':3,
 ' Central or South American':4,
 ' Puerto Rican':3,
 'Do not know':6,
 'Other Spanish':7,
 ' Other Spanish':7,
 'Mexican (Mexicano)':9,
 ' Do not know':10,
 ' Mexican (Mexicano)':9,
 'Mexican-American':12,
 'Chicano':13,
 'All other':1,
 ' Mexican-American':15,
 ' Cuban':18,
 'Central or South American':4,
 ' NA':0,
 'Cuban':18
})
list(set(Data.d_household_summary))
Data['d_household_summary'] = Data['d_household_summary'].map({
    'Child under 18 ever married':0,
 ' Child under 18 ever married':0,
 ' Child under 18 never married':1,
 'Group Quarters- Secondary individual':2,
 ' Spouse of householder':3,
 'Nonrelative of householder':4,
 'Child 18 or older':5,
 ' Other relative of householder':4,
 ' Nonrelative of householder':6,
 ' Group Quarters- Secondary individual':2,
 'Spouse of householder':3,
 'Other relative of householder':6,
 'Child under 18 never married':1,
 ' Householder':7,
 'Householder':7,
 ' Child 18 or older':5
})
list(set(Data.family_members_under_18))
Data['family_members_under_18'] = Data['family_members_under_18'].map({
    'Father only present':0,
 ' Mother only present':1,
 ' Neither parent present':2,
 ' Father only present':0,
 'Neither parent present':2,
 ' Both parents present':3,
 'Mother only present':1,
 'Not in universe':4,
 ' Not in universe':4,
 'Both parents present':3
})
list(set(Data.tax_filer_status))
Data['tax_filer_status'] = Data['tax_filer_status'].map({
    'Single':0,
 'Joint one under 65 & one 65+':1,
 'Joint both under 65':2,
 'Nonfiler':3,
 ' Nonfiler':3,
 'Joint both 65+':4,
 'Head of household':5,
 ' Joint one under 65 & one 65+':1,
 ' Joint both 65+':4,
 ' Single':0,
 ' Head of household':5,
 ' Joint both under 65':2
})

# %%
X = data[['age', 'class_of_worker', 'industry_code', 'occupation_code',
       'education', 'wage_per_hour', 'enrolled_in_edu_inst_lastwk',
       'marital_status', 'major_industry_code', 'major_occupation_code',
       'race', 'hispanic_origin', 'sex', 'member_of_labor_union',
       'reason_for_unemployment', 'full_parttime_employment_stat',
       'capital_gains', 'capital_losses', 'dividend_from_Stocks',
       'tax_filer_status', 'd_household_summary',
       'num_person_Worked_employer', 'family_members_under_18','citizenship',
       'business_or_self_employed', 'fill_questionnaire_veteran_admin',
       'veterans_benefits', 'weeks_worked_in_year', 'year']]
ddd = X.values

# %%
vals = model.predict(ddd)

# %%
res = pd.DataFrame(vals)
res.columns = ['prediction']
res.to_csv("IncomeCensus.csv", index = False)
